-- %% [markdown]
-- ##Grants

-- %%
GRANT USE CATALOG ON CATALOG catalog_smartdata TO `Desarrolladores`; --Permiso Catalogo desarrolladores
GRANT USE CATALOG ON CATALOG catalog_smartdata TO `Cientificos`; --Permiso Catalogo cientificos

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_smartdata.bronze TO `Desarrolladores`;   --usar 
GRANT CREATE ON SCHEMA catalog_smartdata.bronze TO `Desarrolladores`;    --crear
GRANT CREATE TABLE ON SCHEMA catalog_smartdata.bronze TO `Desarrolladores`;

GRANT USE SCHEMA ON SCHEMA catalog_smartdata.golden TO `Cientificos`;   --usar 
GRANT CREATE ON SCHEMA catalog_smartdata.golden TO `Cientificos`;    --crear en 
GRANT CREATE TABLE ON SCHEMA catalog_smartdata.golden TO `Cientificos`;

-- %%
REVOKE ALL PRIVILEGES ON CATALOG catalog_smartdata FROM `cocogrijalva@gmail.com`;

-- %%
GRANT SELECT ON TABLE catalog_smartdata.bronze.clientes TO `cocogrijalva@gmail.com`;--acceso a tablas 
GRANT SELECT ON TABLE catalog_smartdata.golden.clientes_kpis TO `ecmarramirez@hotmail.com`;--acceso a tablas 

-- GRANT ALL PRIVILEGES ON CATALOG demo_catalog TO `Admins`;

-- %%
SHOW GRANTS ON TABLE catalog_smartdata.bronze.clientes;

-- %%
SHOW GRANTS ON SCHEMA catalog_smartdata.bronze;

-- %%
SHOW GRANTS ON CATALOG catalog_smartdata;

-- %%
SHOW GRANTS ON SCHEMA catalog_smartdata.golden;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
SHOW GRANTS ON EXTERNAL LOCATION `exlt-raw`

-- %%
GRANT READ FILES
ON EXTERNAL LOCATION `exlt-raw`
TO `Desarrolladores`;

-- %%
GRANT WRITE FILES
ON EXTERNAL LOCATION `exlt_bronze`
TO `Desarrolladores`;

-- %%
SHOW USERS;

-- %%
drop group `Ingenieros`;
CREATE GROUP `Ingenieros`;

-- %%
ALTER GROUP `Ingenieros`
ADD USER `chgupivi@gmail.com`;

ALTER GROUP `Ingenieros`
ADD USER `gabyjacome12@gamil.com`;
