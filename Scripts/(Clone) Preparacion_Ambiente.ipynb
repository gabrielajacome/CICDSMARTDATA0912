-- %%
%python
dbutils.widgets.removeAll()

-- %%
create widget text storageName default "adlsmartdata0912";

-- %%
DROP CATALOG IF EXISTS catalog_smartdata CASCADE;

-- %%
CREATE CATALOG IF NOT EXISTS catalog_smartdata;

-- %%
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.raw;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.bronze;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.silver;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.golden;
CREATE SCHEMA IF NOT EXISTS catalog_smartdata.exploratory;

CREATE VOLUME IF NOT EXISTS catalog_smartdata.raw.datasets;

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@adlsmartdata0912.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para los archivos de raw del Data Lake';

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt_bronze`
URL 'abfss://bronze@adlsmartdata0912.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas bronze del Data Lake';

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-silver`
URL 'abfss://silver@adlsmartdata0912.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas silver del Data Lake';

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-golden`
URL 'abfss://gold@adlsmartdata0912.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas gold del Data Lake';
